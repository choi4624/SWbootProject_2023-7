# %%
# %pip install "fastapi[all]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fastapi[all]
#   Downloading fastapi-0.100.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 KB 4.3 MB/s eta 0:00:00
# Collecting starlette<0.28.0,>=0.27.0
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 KB 8.5 MB/s eta 0:00:00
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.0.3-py3-none-any.whl (364 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.0/364.0 KB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/i4624/.local/lib/python3.10/site-packages (from fastapi[all]) (4.7.1)
# Collecting python-multipart>=0.0.5
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 9.8 MB/s eta 0:00:00
# Collecting pydantic-extra-types>=2.0.0
#   Downloading pydantic_extra_types-2.0.0-py3-none-any.whl (13 kB)
# Collecting pydantic-settings>=2.0.0
#   Downloading pydantic_settings-2.0.2-py3-none-any.whl (11 kB)
# Collecting itsdangerous>=1.1.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting httpx>=0.23.0
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 KB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.11.2 in /home/i4624/.local/lib/python3.10/site-packages (from fastapi[all]) (3.1.2)
# Collecting email-validator>=2.0.0
#   Downloading email_validator-2.0.0.post2-py3-none-any.whl (31 kB)
# Collecting orjson>=3.2.1
#   Downloading orjson-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 KB 8.6 MB/s eta 0:00:00
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1
#   Downloading ujson-5.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 KB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/lib/python3/dist-packages (from fastapi[all]) (5.4.1)
# Collecting uvicorn[standard]>=0.12.0
#   Downloading uvicorn-0.23.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 KB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.0.0 in /usr/lib/python3/dist-packages (from email-validator>=2.0.0->fastapi[all]) (3.3)
# Collecting dnspython>=2.0.0
#   Downloading dnspython-2.4.0-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 10.6 MB/s eta 0:00:00
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting httpcore<0.18.0,>=0.15.0
#   Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 KB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx>=0.23.0->fastapi[all]) (2020.6.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2>=2.11.2->fastapi[all]) (2.0.1)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Collecting pydantic-core==2.3.0
#   Downloading pydantic_core-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.0 MB/s eta 0:00:00a 0:00:01
# Collecting python-dotenv>=0.21.0
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.7.1-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 KB 9.5 MB/s eta 0:00:00
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/lib/python3/dist-packages (from uvicorn[standard]>=0.12.0->fastapi[all]) (8.0.3)
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 KB 10.8 MB/s eta 0:00:00a 0:00:01
# Collecting websockets>=10.4
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 KB 9.4 MB/s eta 0:00:00
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 11.2 MB/s eta 0:00:0000:0100:01
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.19.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.1 MB/s eta 0:00:00a 0:00:01
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.1.2-py3-none-any.whl (14 kB)
# Installing collected packages: websockets, uvloop, ujson, sniffio, python-multipart, python-dotenv, pydantic-core, orjson, itsdangerous, httptools, h11, exceptiongroup, annotated-types, uvicorn, pydantic, anyio, watchfiles, starlette, pydantic-settings, pydantic-extra-types, httpcore, httpx, fastapi, dnspython, email-validator
# Successfully installed annotated-types-0.5.0 anyio-3.7.1 dnspython-2.4.0 email-validator-2.0.0.post2 exceptiongroup-1.1.2 fastapi-0.100.0 h11-0.14.0 httpcore-0.17.3 httptools-0.6.0 httpx-0.24.1 itsdangerous-2.1.2 orjson-3.9.2 pydantic-2.0.3 pydantic-core-2.3.0 pydantic-extra-types-2.0.0 pydantic-settings-2.0.2 python-dotenv-1.0.0 python-multipart-0.0.6 sniffio-1.3.0 starlette-0.27.0 ujson-5.8.0 uvicorn-0.23.1 uvloop-0.17.0 watchfiles-0.19.0 websockets-11.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install openvino
# %pip install wandb
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openvino
#   Downloading openvino-2023.0.1-11005-cp310-cp310-manylinux2014_x86_64.whl (36.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 10.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.16.6 in /home/i4624/.local/lib/python3.10/site-packages (from openvino) (1.25.1)
# Installing collected packages: openvino
# Successfully installed openvino-2023.0.1
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wandb
#   Downloading wandb-0.15.5-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/lib/python3/dist-packages (from wandb) (2.25.1)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/lib/python3/dist-packages (from wandb) (8.0.3)
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 KB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /home/i4624/.local/lib/python3.10/site-packages (from wandb) (5.9.5)
# Collecting appdirs>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /home/i4624/.local/lib/python3.10/site-packages (from wandb) (4.23.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.28.1-py2.py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.7/214.7 KB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in /usr/lib/python3/dist-packages (from wandb) (5.4.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from wandb) (59.6.0)
# Requirement already satisfied: six>=1.4.0 in /usr/lib/python3/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from sentry-sdk>=1.0.0->wandb) (2020.6.20)
# Collecting urllib3>=1.26.11
#   Downloading urllib3-2.0.3-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 KB 10.6 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=a7603b1e965022499fad022fc23eb89036dd9d957127e06a1f6049230511f824
#   Stored in directory: /home/i4624/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: pathtools, appdirs, urllib3, smmap, setproctitle, docker-pycreds, sentry-sdk, gitdb, GitPython, wandb
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-auth 2.21.0 requires urllib3<2.0, but you have urllib3 2.0.3 which is incompatible.
# Successfully installed GitPython-3.1.32 appdirs-1.4.4 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.28.1 setproctitle-1.3.2 smmap-5.0.0 urllib3-2.0.3 wandb-0.15.5
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/i4624/.local/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: packaging>=20.0 in /home/i4624/.local/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/i4624/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/i4624/.local/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/i4624/.local/lib/python3.10/site-packages (from matplotlib) (4.41.0)
# Requirement already satisfied: cycler>=0.10 in /home/i4624/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in /home/i4624/.local/lib/python3.10/site-packages (from matplotlib) (1.25.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/i4624/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os, pprint, yaml, warnings, math, glob, cv2, random, logging

def warn(*args, **kwargs):
    pass
warnings.warn = warn
warnings.filterwarnings('ignore')
logger = logging.getLogger("anomalib")

import anomalib
from pytorch_lightning import Trainer, seed_everything
from anomalib.config import get_configurable_parameters
from anomalib.data import get_datamodule
from anomalib.models import get_model
from anomalib.utils.callbacks import LoadModelCallback, get_callbacks
from anomalib.utils.loggers import configure_logger, get_experiment_logger

# %%
CONFIG_PATHS = '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/models'
MODEL_CONFIG_PAIRS = {
    'patchcore': f'{CONFIG_PATHS}/patchcore/config.yaml',
    'padim':     f'{CONFIG_PATHS}/padim/config.yaml',
    'cflow':     f'{CONFIG_PATHS}/cflow/config.yaml',
    'dfkde':     f'{CONFIG_PATHS}/dfkde/config.yaml',
    'dfm':       f'{CONFIG_PATHS}/dfm/config.yaml',
    'ganomaly':  f'{CONFIG_PATHS}/ganomaly/config.yaml',
    'stfpm':     f'{CONFIG_PATHS}/stfpm/config.yaml',
    'fastflow':  f'{CONFIG_PATHS}/fastflow/config.yaml',
    'draem':     f'{CONFIG_PATHS}/draem/config.yaml',
    'reverse_distillation': f'{CONFIG_PATHS}/reverse_distillation/config.yaml',
}

# %%
MODEL = 'patchcore' # 'padim', 'cflow', 'stfpm', 'ganomaly', 'dfkde', 'patchcore'

# %%
new_update = {
    "path": '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection',
    'category': 'hazelnut', 
    'image_size': 256,
    'train_batch_size':16,
    'seed': 101
}

# %%
# update yaml key's value
def update_yaml(old_yaml, new_yaml, new_update):
    # load yaml
    with open(old_yaml) as f:
        old = yaml.safe_load(f)
                  
    temp = []
    def set_state(old, key, value):
        if isinstance(old, dict):
            for k, v in old.items():
                if k == 'project':
                    temp.append(k)
                if k == key:
                    if temp and k == 'path':
                        # right now, we don't wanna change `project.path`
                        continue
                    old[k] = value
                elif isinstance(v, dict):
                    set_state(v, key, value)
    
    # iterate over the new update key-value pari
    for key, value in new_update.items():
        set_state(old, key, value)
    
    # save the updated / modified yaml file
    with open(new_yaml, 'w') as f:
        yaml.safe_dump(old, f, default_flow_style=False)

# %%
# let's set a new path location of new config file 
new_yaml_path = CONFIG_PATHS + '/' + list(MODEL_CONFIG_PAIRS.keys())[0] + '_new.yaml'

# run the update yaml method to update desired key's values
update_yaml(MODEL_CONFIG_PAIRS[MODEL], new_yaml_path, new_update)

# %%
with open(new_yaml_path) as f:
    updated_config = yaml.safe_load(f)

# %%
### working condition  
pprint.pprint(updated_config)
# Out:
# {'dataset': {'category': 'hazelnut',
#              'center_crop': 224,
#              'eval_batch_size': 32,
#              'format': 'mvtec',
#              'image_size': 256,
#              'name': 'mvtec',
#              'normalization': 'imagenet',
#              'num_workers': 8,
#              'path': '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection',
#              'task': 'segmentation',
#              'test_split_mode': 'from_dir',
#              'test_split_ratio': 0.2,
#              'tiling': {'apply': False,
#                         'random_tile_count': 16,
#                         'remove_border_count': 0,
#                         'stride': None,
#                         'tile_size': None,
#                         'use_random_tiling': False},
#              'train_batch_size': 16,
#              'transform_config': {'eval': None, 'train': None},
#              'val_split_mode': 'same_as_test',
#              'val_split_ratio': 0.5},
#  'logging': {'log_graph': False, 'logger': []},
#  'metrics': {'image': ['F1Score', 'AUROC'],
#              'pixel': ['F1Score', 'AUROC'],
#              'threshold': {'manual_image': None,
#                            'manual_pixel': None,
#                            'method': 'adaptive'}},
#  'model': {'backbone': 'wide_resnet50_2',
#            'coreset_sampling_ratio': 0.1,
#            'layers': ['layer2', 'layer3'],
#            'name': 'patchcore',
#            'normalization_method': 'min_max',
#            'num_neighbors': 9,
#            'pre_trained': True},
#  'optimization': {'export_mode': None},
#  'project': {'path': './results', 'seed': 101},
#  'trainer': {'accelerator': 'auto',
#              'accumulate_grad_batches': 1,
#              'auto_lr_find': False,
#              'auto_scale_batch_size': False,
#              'benchmark': False,
#              'check_val_every_n_epoch': 1,
#              'default_root_dir': None,
#              'detect_anomaly': False,
#              'deterministic': False,
#              'devices': 1,
#              'enable_checkpointing': True,
#              'enable_model_summary': True,
#              'enable_progress_bar': True,
#              'fast_dev_run': False,
#              'gradient_clip_algorithm': 'norm',
#              'gradient_clip_val': 0,
#              'limit_predict_batches': 1.0,
#              'limit_test_batches': 1.0,
#              'limit_train_batches': 1.0,
#              'limit_val_batches': 1.0,
#              'log_every_n_steps': 50,
#              'max_epochs': 1,
#              'max_steps': -1,
#              'max_time': None,
#              'min_epochs': None,
#              'min_steps': None,
#              'move_metrics_to_cpu': False,
#              'multiple_trainloader_mode': 'max_size_cycle',
#              'num_nodes': 1,
#              'num_sanity_val_steps': 0,
#              'overfit_batches': 0.0,
#              'plugins': None,
#              'precision': 32,
#              'profiler': None,
#              'reload_dataloaders_every_n_epochs': 0,
#              'replace_sampler_ddp': True,
#              'strategy': None,
#              'sync_batchnorm': False,
#              'track_grad_norm': -1,
#              'val_check_interval': 1.0},
#  'visualization': {'image_save_path': None,
#                    'log_images': True,
#                    'mode': 'full',
#                    'save_images': True,
#                    'show_images': False}}

# %%
# It will return the configurable parameters in DictConfig object.
config = get_configurable_parameters(
    model_name=updated_config['model']['name'],
    config_path=new_yaml_path
)

# %%
from torchvision.datasets.folder import IMG_EXTENSIONS

img_paths = sorted(
        [
            os.path.join(dirpath,filename) 
            for dirpath, _, filenames in os.walk(
                os.path.join(config.dataset.path, config.dataset.category, 'test')
            )
            for filename in filenames if filename.endswith(IMG_EXTENSIONS) 
            and not filename.startswith(".")
        ],
    )

img_paths = [img_path for img_path in img_paths if not "good" in img_path]
img_paths = random.sample(img_paths, 10)
img_paths
# Out:
# ['/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/015.png',
#  '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/crack/007.png',
#  '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/004.png',
#  '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/014.png',
#  '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/print/016.png',
#  '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/003.png',
#  '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/crack/004.png',
#  '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/cut/011.png',
#  '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/print/014.png',
#  '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/002.png']

# %%
# Out:
# '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/cut/014.png'

# %%
infer_resutls = "/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/infer_results/"
os.makedirs(infer_resutls, exist_ok=True)

# %%
updated_config['model']['name']
# Out:
# 'patchcore'

# %%
for infer_img_path in img_paths:
    # !python3 /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/tools/inference/lightning_inference.py --config /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/models/patchcore/config.yaml    --weights /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/fastapi/results/patchcore/mvtec/hazelnut/run/weights/model.ckpt         --input {infer_img_path}  --output ./infer_results      --visualization_mode "full"
# Out:
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:243: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:280: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/utils/callbacks/__init__.py:142: UserWarning: Export option: None not found. Defaulting to no model export
#   warnings.warn(f"Export option: {config.optimization.export_mode} not found. Defaulting to no model export")
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/015.png
# Predicting DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/015.png
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  2.26it/s]
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:243: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:280: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/utils/callbacks/__init__.py:142: UserWarning: Export option: None not found. Defaulting to no model export
#   warnings.warn(f"Export option: {config.optimization.export_mode} not found. Defaulting to no model export")
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/crack/007.png
# Predicting DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/crack/007.png
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  1.58it/s]
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:243: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:280: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/utils/callbacks/__init__.py:142: UserWarning: Export option: None not found. Defaulting to no model export
#   warnings.warn(f"Export option: {config.optimization.export_mode} not found. Defaulting to no model export")
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/004.png
# Predicting DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/004.png
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  2.01it/s]
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:243: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:280: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/utils/callbacks/__init__.py:142: UserWarning: Export option: None not found. Defaulting to no model export
#   warnings.warn(f"Export option: {config.optimization.export_mode} not found. Defaulting to no model export")
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/014.png
# Predicting DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/014.png
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  2.33it/s]
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:243: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:280: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/utils/callbacks/__init__.py:142: UserWarning: Export option: None not found. Defaulting to no model export
#   warnings.warn(f"Export option: {config.optimization.export_mode} not found. Defaulting to no model export")
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/print/016.png
# Predicting DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/print/016.png
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  1.86it/s]
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:243: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:280: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/utils/callbacks/__init__.py:142: UserWarning: Export option: None not found. Defaulting to no model export
#   warnings.warn(f"Export option: {config.optimization.export_mode} not found. Defaulting to no model export")
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/003.png
# Predicting DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/003.png
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  2.23it/s]
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:243: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:280: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/utils/callbacks/__init__.py:142: UserWarning: Export option: None not found. Defaulting to no model export
#   warnings.warn(f"Export option: {config.optimization.export_mode} not found. Defaulting to no model export")
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/crack/004.png
# Predicting DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/crack/004.png
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  2.04it/s]
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:243: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:280: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/utils/callbacks/__init__.py:142: UserWarning: Export option: None not found. Defaulting to no model export
#   warnings.warn(f"Export option: {config.optimization.export_mode} not found. Defaulting to no model export")
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/cut/011.png
# Predicting DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/cut/011.png
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  2.23it/s]
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:243: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:280: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/utils/callbacks/__init__.py:142: UserWarning: Export option: None not found. Defaulting to no model export
#   warnings.warn(f"Export option: {config.optimization.export_mode} not found. Defaulting to no model export")
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/print/014.png
# Predicting DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/print/014.png
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:243: UserWarning: The seed value is now fixed to 0. Up to v0.3.7, the seed was not fixed when the seed value was set to 0. If you want to use the random seed, please select `None` for the seed value (`null` in the YAML file) or remove the `seed` key from the YAML file.
#   warn(
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/config/config.py:280: UserWarning: config.project.unique_dir is set to False. This does not ensure that your results will be written in an empty directory and you may overwrite files.
#   warn(
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `PrecisionRecallCurve` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# FeatureExtractor is deprecated. Use TimmFeatureExtractor instead. Both FeatureExtractor and TimmFeatureExtractor will be removed in a future release.
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/anomalib/src/anomalib/utils/callbacks/__init__.py:142: UserWarning: Export option: None not found. Defaulting to no model export
#   warnings.warn(f"Export option: {config.optimization.export_mode} not found. Defaulting to no model export")
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:55: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v2.0. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_predict_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /home/i4624/.local/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `ROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# /home/i4624/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 20 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/002.png
# Predicting DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]image py there is
# /home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/mvtec_anomaly_detection/hazelnut/test/hole/002.png
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:00<00:00,  1.30it/s]

# %%
print(os.listdir(infer_resutls))
infer_resutls
# Out:
# []
# '/home/i4624/vscode/gitclone/SWbootProject_2023-7/2nd_cnn/content/infer_results/'

# %%
# %pip install Namespace
# %pip install ArgumentParser
# %pip install Trainer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Namespace in /home/i4624/.local/lib/python3.10/site-packages (0.1.4)
# Requirement already satisfied: modcall<0.2.0,>=0.1.0 in /home/i4624/.local/lib/python3.10/site-packages (from Namespace) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ArgumentParser in /home/i4624/.local/lib/python3.10/site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Trainer
#   Downloading trainer-0.0.28-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 KB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /home/i4624/.local/lib/python3.10/site-packages (from Trainer) (2023.6.0)
# Requirement already satisfied: torch>=1.7 in /home/i4624/.local/lib/python3.10/site-packages (from Trainer) (2.0.1)
# Collecting tensorboard
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 11.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: psutil in /home/i4624/.local/lib/python3.10/site-packages (from Trainer) (5.9.5)
# Collecting coqpit
#   Downloading coqpit-0.0.17-py3-none-any.whl (13 kB)
# Collecting soundfile
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (11.7.101)
# Requirement already satisfied: jinja2 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (3.1.2)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (11.4.0.1)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (10.2.10.91)
# Requirement already satisfied: networkx in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (3.1)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (10.9.0.58)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (8.5.0.96)
# Requirement already satisfied: triton==2.0.0 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (2.0.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (11.7.99)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (2.14.3)
# Requirement already satisfied: sympy in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (1.12)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (4.7.1)
# Requirement already satisfied: filelock in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (3.12.2)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (11.7.91)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/i4624/.local/lib/python3.10/site-packages (from torch>=1.7->Trainer) (11.7.4.91)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7->Trainer) (59.6.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7->Trainer) (0.37.1)
# Requirement already satisfied: lit in /home/i4624/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.7->Trainer) (16.0.6)
# Requirement already satisfied: cmake in /home/i4624/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.7->Trainer) (3.26.4)
# Collecting cffi>=1.0
#   Downloading cffi-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.8/441.8 KB 11.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/i4624/.local/lib/python3.10/site-packages (from tensorboard->Trainer) (2.21.0)
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.56.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 11.3 MB/s eta 0:00:0000:0100:01
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting absl-py>=0.4
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 KB 10.7 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 11.2 MB/s eta 0:00:0000:0100:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 KB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3/dist-packages (from tensorboard->Trainer) (2.25.1)
# Requirement already satisfied: protobuf>=3.19.6 in /home/i4624/.local/lib/python3.10/site-packages (from tensorboard->Trainer) (4.23.3)
# Requirement already satisfied: numpy>=1.12.0 in /home/i4624/.local/lib/python3.10/site-packages (from tensorboard->Trainer) (1.25.1)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 KB 10.8 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 KB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/i4624/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->Trainer) (5.3.1)
# Collecting urllib3<2.0
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 KB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/i4624/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->Trainer) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard->Trainer) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/i4624/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->Trainer) (4.9)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: mpmath>=0.19 in /home/i4624/.local/lib/python3.10/site-packages (from sympy->torch>=1.7->Trainer) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/i4624/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->Trainer) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->Trainer) (3.2.0)
# Installing collected packages: urllib3, tensorboard-data-server, requests-oauthlib, pycparser, MarkupSafe, markdown, grpcio, coqpit, absl-py, werkzeug, cffi, soundfile, google-auth-oauthlib, tensorboard, Trainer
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.3
#     Uninstalling urllib3-2.0.3:
#       Successfully uninstalled urllib3-2.0.3
# Successfully installed MarkupSafe-2.1.3 Trainer-0.0.28 absl-py-1.4.0 cffi-1.15.1 coqpit-0.0.17 google-auth-oauthlib-1.0.0 grpcio-1.56.0 markdown-3.4.3 pycparser-2.21 requests-oauthlib-1.3.1 soundfile-0.12.1 tensorboard-2.13.0 tensorboard-data-server-0.7.1 urllib3-1.26.16 werkzeug-2.3.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install DictConfig
# %pip install Tensor
# %pip install nn
# %pip install Path
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement DictConfig (from versions: none)
# ERROR: No matching distribution found for DictConfig
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Tensor
#   Downloading tensor-0.3.6.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 KB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYaml in /usr/lib/python3/dist-packages (from Tensor) (5.4.1)
# Collecting Twisted
#   Downloading Twisted-22.10.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.1 MB/s eta 0:00:0000:0100:01
# Collecting construct
#   Downloading construct-2.10.68.tar.gz (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 KB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf in /home/i4624/.local/lib/python3.10/site-packages (from Tensor) (4.23.3)
# Collecting pysnmp
#   Downloading pysnmp-4.4.12-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 KB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1>=0.2.3 in /home/i4624/.local/lib/python3.10/site-packages (from pysnmp->Tensor) (0.5.0)
# Collecting pycryptodomex
#   Downloading pycryptodomex-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 11.2 MB/s eta 0:00:00a 0:00:01
# Collecting pysmi
#   Downloading pysmi-0.3.4-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.0/80.0 KB 11.4 MB/s eta 0:00:00
# Collecting zope.interface>=4.4.2
#   Downloading zope.interface-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 KB 10.8 MB/s eta 0:00:00
# Collecting hyperlink>=17.1.1
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 KB 9.8 MB/s eta 0:00:00
# Collecting Automat>=0.8.0
#   Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Collecting incremental>=21.3.0
#   Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Collecting constantly>=15.1
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: attrs>=19.2.0 in /home/i4624/.local/lib/python3.10/site-packages (from Twisted->Tensor) (23.1.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /home/i4624/.local/lib/python3.10/site-packages (from Twisted->Tensor) (4.7.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from Automat>=0.8.0->Twisted->Tensor) (1.16.0)
# Requirement already satisfied: idna>=2.5 in /usr/lib/python3/dist-packages (from hyperlink>=17.1.1->Twisted->Tensor) (3.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from zope.interface>=4.4.2->Twisted->Tensor) (59.6.0)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 9.8 MB/s eta 0:00:00
# Building wheels for collected packages: Tensor, construct
#   Building wheel for Tensor (setup.py) ... done
#   Created wheel for Tensor: filename=tensor-0.3.6-py3-none-any.whl size=71567 sha256=1cb5dde27777427d5892e31c4efc3a702a118f49aa5c172aa4678960bc9be17d
#   Stored in directory: /home/i4624/.cache/pip/wheels/b8/d7/e8/f4760f8bcef039fce5899d36f67a8447aaeb1b816741791610
#   Building wheel for construct (setup.py) ... done
#   Created wheel for construct: filename=construct-2.10.68-py3-none-any.whl size=59227 sha256=a0971e67b37eb7265a474b6150242ceed855625d096e3be2ba6699b82753b94e
#   Stored in directory: /home/i4624/.cache/pip/wheels/ad/d3/ab/fd87f53c1e3c4b77c0bbcf272051ccc8455a00c524be951ea0
# Successfully built Tensor construct
# Installing collected packages: ply, incremental, constantly, zope.interface, pysmi, pycryptodomex, hyperlink, construct, Automat, Twisted, pysnmp, Tensor
# Successfully installed Automat-22.10.0 Tensor-0.3.6 Twisted-22.10.0 constantly-15.1.0 construct-2.10.68 hyperlink-21.0.0 incremental-22.10.0 ply-3.11 pycryptodomex-3.18.0 pysmi-0.3.4 pysnmp-4.4.12 zope.interface-6.0
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nn
#   Downloading nn-0.1.1.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: nn
#   Building wheel for nn (setup.py) ... done
#   Created wheel for nn: filename=nn-0.1.1-py3-none-any.whl size=5723 sha256=77d1661d0117fc7fb6f8b2e78998c65f6da766f296f2f7f5d4ae1a9654e3a4f5
#   Stored in directory: /home/i4624/.cache/pip/wheels/60/62/98/7126b3684829be2701b0f07444922e84b3304646574a159431
# Successfully built nn
# Installing collected packages: nn
# Successfully installed nn-0.1.1
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Path
#   Downloading path-16.7.1-py3-none-any.whl (25 kB)
# Installing collected packages: Path
# Successfully installed Path-16.7.1
# Note: you may need to restart the kernel to use updated packages.
